# %% [markdown]
# Documentation for the Taxonomic Information Registry is lagging way behind. I've been dumping properties of various kinds into the TIR table's key/value pairs with no documentation anywhere. I built this notebook to help document the properties by building a property registry table containing property names, types, definitions, and maybe some additional information in future.

# %%
import requests,configparser

# %%
# Get API keys and any other config details from a file that is external to the code.
config = configparser.RawConfigParser()
config.read_file(open(r'../config/stuff.py'))

# %%
# Build base URL with API key using input from the external config.
def getBaseURL():
    gc2APIKey = config.get('apiKeys','apiKey_GC2_BCB').replace('"','')
    apiBaseURL = "https://gc2.mapcentia.com/api/v1/sql/bcb?key="+gc2APIKey
    return apiBaseURL

# %%
# Basic function to insert registration info pairs into TIR
def registerProperty(name,proptype,definition):
    # Check to see if property name already exists
    r = requests.get(getBaseURL()+"&q=SELECT gid FROM tir.propertyregistry WHERE name='"+name+"'").json()

    # Insert or update based on name query
    if len(r["features"]) == 0:
        q_property = getBaseURL()+"&q=INSERT INTO tir.propertyregistry (name,proptype,definition) VALUES ('"+name+"','"+proptype+"','"+definition+"')"
    else:
        q_property = getBaseURL()+"&q=UPDATE tir.propertyregistry SET proptype='"+proptype+"', definition='"+definition+"' WHERE name='"+name+"'"

    return requests.get(q_property).json()

# %% [markdown]
# This is an incomplete solution for this. I spent a few minutes trying to figure out a method using ipywidgets or web2py that would make this more of a lasting solution, but I ran out of time. I like the idea of using code something like this to drive the documentation of concepts being recorded in our data, but we should come up with something more robust.
#
# What this next block does is work through all of the unique key names that have been recorded in the information fields for the TIR so far. Once it assembles that list, it iterates through and prompts for a property type and definition to go along with the name. We will probably refine the keys over time as I'm seeing a few things I would do differently with the concepts in retrospect. We will also want to add further definition to the keys, particularly some sort of URL reference to deeper level information about the concept. The information from this goes into a tir.propertyregistry table for use by applications.

# %%
r_registrationKeys = requests.get(getBaseURL()+"&q=SELECT array_agg(DISTINCT key) FROM (SELECT skeys(registration) AS key FROM tir.tir2) AS temp").json()
r_itisKeys = requests.get(getBaseURL()+"&q=SELECT array_agg(DISTINCT key) FROM (SELECT skeys(itis) AS key FROM tir.tir2) AS temp").json()
r_tessKeys = requests.get(getBaseURL()+"&q=SELECT array_agg(DISTINCT key) FROM (SELECT skeys(tess) AS key FROM tir.tir2) AS temp").json()
r_natureserveKeys = requests.get(getBaseURL()+"&q=SELECT array_agg(DISTINCT key) FROM (SELECT skeys(natureserve) AS key FROM tir.tir2) AS temp").json()

keyList = []
keyList.extend(r_registrationKeys["features"][0]["properties"]["array_agg"][1:-1].split(","))
keyList.extend(r_itisKeys["features"][0]["properties"]["array_agg"][1:-1].split(","))
keyList.extend(r_tessKeys["features"][0]["properties"]["array_agg"][1:-1].split(","))
keyList.extend(r_natureserveKeys["features"][0]["properties"]["array_agg"][1:-1].split(","))

for key in keyList:
    thisProperty = {}
    thisProperty["name"] = key
    thisProperty["proptype"] = ""
    thisProperty["definition"] = ""
    
    # Check to see if the property is already defined
    r_checkProperty = requests.get(getBaseURL()+"&q=SELECT * FROM tir.propertyregistry WHERE name='"+thisProperty["name"]+"'").json()
    if len(r_checkProperty["features"]) == 1:
        thisProperty["proptype"] = r_checkProperty["features"][0]["properties"]["proptype"]
        thisProperty["definition"] = r_checkProperty["features"][0]["properties"]["definition"]
    
    print (thisProperty["name"])
    thisProperty["proptype"] = input("Property Type: ")
    thisProperty["definition"] = input("Definition: ")
    print (registerProperty(thisProperty["name"],thisProperty["proptype"],thisProperty["definition"]))
# Out:
# DOI
# Property Type: string
# Definition: For GAP species registrations - the Digital Object Identifier assigned to the published habitat map
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# EGTID
# Property Type: integer
# Definition: The numeric part of a NatureServe identifier for a species
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# GAP_CommonName
# Property Type: string
# Definition: GAP species common name
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# GAP_ScientificName
# Property Type: GAP species scientific name
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# GAP_SpeciesCode
# Property Type: GAP species code
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# IPDS
# Property Type: integer
# Definition: Record number from the USGS Integrated Publishing Data System
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# ITIS_TSN
# Property Type: integer
# Definition: Taxonomic Serial Number from the Integrated Taxonomic Information System
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# NatureServeElementCode
# Property Type: Full NatureServe Element Code associated with the taxon
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# registrationDate
# Property Type: datetime
# Definition: Date/time stamp for when the registration of a taxon occurred
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# ScienceBaseItemID
# Property Type: string
# Definition: ScienceBase Item identifier associated with the taxon being registered
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.065}
# SGCN_ScientificName_Submitted
# Property Type: The scientific name submitted by a state under the Species of Greatest Conservation Need process
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# acceptedTSN
# Property Type: integer
# Definition: Returned from ITIS, this is the accepted TSN for the taxon
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# cacheDate
# Property Type: datetime
# Definition: Date/time stamp generated and placed in any of the information pools to indicate when the information was retrieved and cached
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Class
# Property Type: string
# Definition: Taxonomic class from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# createDate
# Property Type: date
# Definition: For ITIS records, the date that the taxonomic entry was created in ITIS
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# discoveredTSN
# Property Type: For ITIS records, the TSN that was discovered via name search
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Division
# Property Type: string
# Definition: Taxonomic division from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.058}
# Family
# Property Type: string
# Definition: Taxonomic family from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Genus
# Property Type: Taxonomic genus name from the taxonomic authority
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Infraclass
# Property Type: string
# Definition: Taxonomic infraclass name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Infrakingdom
# Property Type: string
# Definition: Taxonomic infrakingdom name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Infraorder
# Property Type: string
# Definition: Taxonomic infraorder name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Infraphylum
# Property Type: string
# Definition: Taxonomic infraphylum name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# itisMatchMethod
# Property Type: string
# Definition: String indicating how an ITIS match was made (exact or fuzzy match), including the name used in a search
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Kingdom
# Property Type: string
# Definition: Taxonomic kingdom name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# nameWInd
# Property Type: string
# Definition: Scientific name with indicators from ITIS
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# nameWOInd
# Property Type: string
# Definition: Scientific name without indicators from ITIS
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Order
# Property Type: string
# Definition: Taxonomic order name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# Phylum
# Property Type: string
# Definition: Taxonomic phylum name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# rank
# Property Type: string
# Definition: Taxonomic rank of the taxon record from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Species
# Property Type: string
# Definition: Taxonomic species name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Subclass
# Property Type: string
# Definition: Taxonomic subclass name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Subdivision
# Property Type: string
# Definition: Taxonomic subdivision name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Subfamily
# Property Type: string
# Definition: Taxonomic subfamily name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Subgenus
# Property Type: string
# Definition: Taxonomic subgenus name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# Subkingdom
# Property Type: string
# Definition: Taxonomic subkingdom name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# Suborder
# Property Type: string
# Definition: Taxonomic suborder name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Subphylum
# Property Type: string
# Definition: Taxonomic subphylum name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Subspecies
# Property Type: string
# Definition: Taxonomic subspecies name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Subtribe
# Property Type: string
# Definition: Taxonomic subtribe name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# Superclass
# Property Type: string
# Definition: Taxonomic superclass name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# Superdivision
# Property Type: string
# Definition: Taxonomic superdivision name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Superfamily
# Property Type: string
# Definition: Taxonomic superfamily name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# Superorder
# Property Type: string
# Definition: Taxonomic superorder name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# Superphylum
# Property Type: string
# Definition: Taxonomic superphylum name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Tribe
# Property Type: Taxonomic tribe name from the taxonomic authority
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# tsn
# Property Type: integer
# Definition: The ITIS Taxonomic Serial Number for the taxon record based on the match method
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# updateDate
# Property Type: date
# Definition: For ITIS information, the date the taxonomic record was last updated
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# usage
# Property Type: For ITIS information, the usage flag for the taxonomic record returned (valid, invalid, accepted, not accepted)
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# Variety
# Property Type: string
# Definition: Taxonomic variety name from the taxonomic authority
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# vernacular:English
# Property Type: string
# Definition: For ITIS information, the common name in English
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# vernacular:French
# Property Type: string
# Definition: For ITIS information, the common name in French
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# vernacular:Hawaiian
# Property Type: string
# Definition: For ITIS information, the common name in Hawaiian
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# "vernacular:Native American"
# Property Type: string
# Definition: For ITIS information, the common name in a Native American language
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# vernacular:Portuguese
# Property Type: string
# Definition: For ITIS information, the common name in Portuguese
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# vernacular:Spanish
# Property Type: string
# Definition: For ITIS information, the common name in Spanish
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# vernacular:unspecified
# Property Type: string
# Definition: For ITIS information, the common name in an unspecified language
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# cacheDate
# Property Type: datetime
# Definition: Date/time stamp generated and placed in any of the information pools to indicate when the information was retrieved and cached
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# CommonName
# Property Type: For FWS TESS records, a common name for the taxon
# Definition:
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.066}
# entityId
# Property Type: integer
# Definition: For FWS TESS records, an identifier for the record
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# ListingDate
# Property Type: date
# Definition: For FWS TESS records, the listing date for the taxon
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# PopulationDescription
# Property Type: For FWS TESS records, the description of the listed population
# Definition: For FWS TESS records, a common name for the taxon
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# result
# Property Type: string
# Definition: A string indicating the result of a search for a particular type of information
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# SpeciesCode
# Property Type: string
# Definition: For FWS TESS information, the species code for the taxon
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.064}
# Status
# Property Type: string
# Definition: A coded string indicating the listing/protection status for a species
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# StatusText
# Property Type: string
# Definition: A string indicating the listing/protection status for a species (defines status)
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# tsn
# Property Type: integer
# Definition: The ITIS Taxonomic Serial Number for a taxon - may be found in information sources outside of ITIS
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.065}
# cacheDate
# Property Type: datetime
# Definition: Date/time stamp generated and placed in any of the information pools to indicate when the information was retrieved and cached - may be found in multiple information sources
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# elementGlobalID
# Property Type: string
# Definition: NatureServe Element Global ID - used as a primary identifier across NatureServe data systems
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# globalStatusLastReviewed
# Property Type: date
# Definition: The date that NatureServe global status was last reviewed
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# GlobalStatusRank
# Property Type: string
# Definition: Coded value for the NatureServe global status of a species
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.072}
# roundedGlobalStatusRankDescription
# Property Type: string
# Definition: Descriptive text for the NatureServe global status - defines GlobalStatusRank
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Alabama
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# StateCode:Alaska
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Arizona
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# StateCode:Arkansas
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:California
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Colorado
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Connecticut
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Delaware
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# "StateCode:District of Columbia"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Florida
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# StateCode:Georgia
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Hawaii
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.069}
# StateCode:Idaho
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Illinois
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Indiana
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.064}
# StateCode:Iowa
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Kansas
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Kentucky
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Louisiana
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Maine
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Maryland
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# StateCode:Massachusetts
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# StateCode:Michigan
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.064}
# StateCode:Minnesota
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Mississippi
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Missouri
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Montana
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# "StateCode:Navajo Nation"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Nebraska
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Nevada
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# "StateCode:New Hampshire"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# "StateCode:New Jersey"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.063}
# "StateCode:New Mexico"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# "StateCode:New York"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# "StateCode:North Carolina"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# "StateCode:North Dakota"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Ohio
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.064}
# StateCode:Oklahoma
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Oregon
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Pennsylvania
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# "StateCode:Rhode Island"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# "StateCode:South Carolina"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# "StateCode:South Dakota"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.065}
# StateCode:Tennessee
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Texas
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Utah
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# StateCode:Vermont
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# StateCode:Virginia
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# StateCode:Washington
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.059}
# "StateCode:West Virginia"
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Wisconsin
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# StateCode:Wyoming
# Property Type: string
# Definition: String indicating NatureServe status for a particular state
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.062}
# status
# Property Type: string
# Definition: A coded string indicating the listing/protection status for a species
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.061}
# usNationalStatusLastReviewed
# Property Type: date
# Definition: Date the US National status was last reviewed in NatureServe information
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.06}
# usNationalStatusRankCode
# Property Type: string
# Definition: US National Status Rank Code in NatureServe
# {'auth_check': {'session': None, 'success': True, 'auth_level': None}, 'affected_rows': 1, 'success': True, '_execution_time': 0.069}
